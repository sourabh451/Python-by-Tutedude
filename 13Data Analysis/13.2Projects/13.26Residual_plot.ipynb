# %%
# RESIDUAL PLOT
# RESIDUAL VALUE
import seaborn as sns
flights = sns.load_dataset("flights")

# %%
sns.residplot(data=flights, x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>
